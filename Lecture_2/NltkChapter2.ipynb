# %%
import nltk , re, pprint
from nltk import word_tokenize

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
print(len(raw))
print(raw[:75])
# Out:
# 1176812
# ﻿The Project Gutenberg eBook of Crime and Punishment, by Fyodor Dostoevsky

# %%
tokens= word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
print(len(tokens))
# Out:
# 257058

# %%
tokens[:10]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'eBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by']

# %%
text= nltk.Text(tokens)
print(type(text))
print(text[1024:1062])
# Out:
# <class 'nltk.text.Text'>
# ['insight', 'impresses', 'us', 'as', 'wisdom', '...', 'that', 'wisdom', 'of', 'the', 'heart', 'which', 'we', 'seek', 'that', 'we', 'may', 'learn', 'from', 'it', 'how', 'to', 'live', '.', 'All', 'his', 'other', 'gifts', 'came', 'to', 'him', 'from', 'nature', ',', 'this', 'he', 'won', 'for']

# %%
text.collocations() # words that are frequently togather.
# Out:
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Project Gutenberg-tm; Porfiry Petrovitch; Amalia Ivanovna;
# great deal; young man; Nikodim Fomitch; Project Gutenberg; Ilya
# Petrovitch; Andrey Semyonovitch; Hay Market; Dmitri Prokofitch; Good
# heavens

# %%
raw.find("PART I") #find
# Out:
# 5575

# %%
raw.rfind("End of Project Gutenberg's Crime") #find in reverse order
# Out:
# -1

# %%
raw = raw[185332:-1] #slicing and reindixing.
raw.find("PART I")
# Out:
# 16014

# %% [markdown]
# ## Work with HTML

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode('utf8')
html[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
print(html)
# Out:
# <!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN" "http://www.w3.org/TR/REC-html40/loose.dtd">
# <html>
# <head>
# <title>BBC NEWS | Health | Blondes 'to die out in 200 years'</title>
# <meta name="keywords" content="BBC, News, BBC News, news online, world, uk, international, foreign, british, online, service">
# <meta name="OriginalPublicationDate" content="2002/09/27 11:51:55">
# <meta name="UKFS_URL" content="/1/hi/health/2284783.stm">
# <meta name="IFS_URL" content="/2/hi/health/2284783.stm">
# <meta name="HTTP-EQUIV" content="text/html;charset=iso-8859-1">
# <meta name="Headline" content="Blondes 'to die out in 200 years'">
# <meta name="Section" content="Health">
# <meta name="Description" content="Natural blondes are an endangered species and will die out by 2202, a study suggests.">
# <!-- GENMaps-->
# <map name="banner">
# <area alt="BBC NEWS" coords="7,9,167,32" href="http://news.bbc.co.uk/1/hi.html" shape="RECT">
# </map>
#
# ...

# %%
from bs4 import BeautifulSoup
raw = BeautifulSoup(html, 'html.parser').get_text()
tokens = word_tokenize(raw)
tokens[:20]
# Out:
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH']

# %%
tokens = tokens[110:390]
text = nltk.Text(tokens)
text.concordance('gene')
# Out:
# Displaying 4 of 4 matches:
# blonde hair is caused by a recessive gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %% [markdown]
# ### Feed Parser

# %%
import feedparser
llog= feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")
llog['feed']['title']
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[5]
post.title
# Out:
# 'Tatar Journalism in Tatar'

# %%
content = post.content[0].value
content[:70]
# Out:
# '<p><a href="https://en.wikipedia.org/wiki/Tatar_language">Tatar</a></p'

# %%
raw = BeautifulSoup(content, 'html.parser').get_text()
word_tokenize(raw)
# Out:
# ['Tatar',
#  'Tatars',
#  "''",
#  'Tatar',
#  'Journalists',
#  'More',
#  'Likely',
#  'to',
#  'Cover',
#  'Controversial',
#  'Topics',
#  'When',
#  'They',
#  'Write',
#  'or',
#  'Speak',
#  'in',
#  'Tatar',
#  ',',
#  'One',
#  'of',
#  'Their',
#  'Number',
#  'Says',
#  "''",
#  'Paul',
#  'Goble',
#  ',',
#  'Window',
#  'on',
#  'Eurasia',
#  '—',
#  'New',
#  'SeriesMonday',
#  ',',
#  'August',
#  '28',
#  ',',
#  '2023',
#  'Staunton',
#  ',',
#  'Aug.',
#  '28',
#  '–',
#  'Tatar',
#  'journalists',
#  'are',
#  'more',
#  'likely',
#  'to',
#  'cover',
#  'controversial',
#  'topics',
#  'when',
#  'they',
#  'write',
#  'or',
#  'speak',
#  'in',
#  'Tatar',
#  'than',
#  'they',
#  'are',
#  'when',
#  'they',
#  'use',
#  'Russian',
#  ',',
#  'according',
#  'to',
#  'Alfiya',
#  'Minnullina',
#  ',',
#  'one',
#  'of',
#  'the',
#  'founders',
#  'of',
#  'the',
#  'online',
#  'newspaper',
#  'Intertat',
#  ',',
#  'calling',
#  'attention',
#  'to',
#  'a',
# ...

# %%
file= open("PeterPan.txt","r", encoding="utf-8-sig")
for lines in file:
    print(lines.strip())
# Out:
# The Project Gutenberg eBook of Peter Pan, by James M. Barrie
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United States, you
# will have to check the laws of the country where you are located before
# using this eBook.
#
# Title: Peter Pan
# Peter Pan and Wendy
#
# Author: James M. Barrie
#
# Release Date: July, 1991 [eBook #16]
# [Most recently updated: February 15, 2021]
#
# Language: English
#
# Character set encoding: UTF-8
#
# Produced by: Duncan Research
#
# *** START OF THE PROJECT GUTENBERG EBOOK PETER PAN ***
#
#
#
#
# Peter Pan
#
# [PETER AND WENDY]
#
# by J. M. Barrie [James Matthew Barrie]
#
# A Millennium Fulcrum Edition produced in 1991 by Duncan Research. Note
# ...

# %%
a = [1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1]
b = [' ' * 2 * (7 - i) + 'very' * i for i in a]
for line in b:
    print(line)
# Out:
#             very
#           veryvery
#         veryveryvery
#       veryveryveryvery
#     veryveryveryveryvery
#   veryveryveryveryveryvery
# veryveryveryveryveryveryvery
#   veryveryveryveryveryvery
#     veryveryveryveryvery
#       veryveryveryvery
#         veryveryvery
#           veryvery
#             very

# %%
sentence = "My name is neha and i am 24 years old and i study informatics"
tokens = nltk.tokenize(sentence)
tokens
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3108\2840775161.py in <module>
#       1 sentence = "My name is neha and i am 24 years old and i study informatics"
# ----> 2 tokens = nltk.tokenize(sentence)
#       3 tokens
#
# TypeError: 'module' object is not callable
